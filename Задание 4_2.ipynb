# %%
import numpy
import pandas
import matplotlib.pyplot

df = pandas.DataFrame()
df.insert(0 , 'число' , range(1,11))
df.insert(1 , 'квадрат' , df['число']**2)
print(df)
# Out:
#    число  квадрат
# 0      1        1
# 1      2        4
# 2      3        9
# 3      4       16
# 4      5       25
# 5      6       36
# 6      7       49
# 7      8       64
# 8      9       81
# 9     10      100

# %%
df2 = df[df['число'] % 2 == 0]
df2 = df2.drop(['число'] , axis='columns')
print(df2)
# Out:
#    квадрат
# 1        4
# 3       16
# 5       36
# 7       64
# 9      100
