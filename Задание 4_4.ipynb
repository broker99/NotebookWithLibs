# %%
import numpy
import pandas 
import matplotlib.pyplot

df=pandas.read_csv('winequality-white.csv', delimiter=';')
df=df.loc[df['residual sugar'] < 1]
df=df[['density','pH']] 

matplotlib.pyplot.hist(df[['density','pH']])
print(df)
# Out:
#       density    pH
# 54    0.99300  3.05
# 172   0.99020  3.03
# 209   0.99300  3.22
# 223   0.99360  3.42
# 259   0.99040  3.28
# ...       ...   ...
# 4804  0.98934  3.24
# 4877  0.99286  3.25
# 4878  0.99234  3.24
# 4891  0.99074  3.24
# 4897  0.98941  3.26
#
# [77 rows x 2 columns]

# %%
x = numpy.array(range(1,100))
y = x ** 2
matplotlib.pyplot.plot(df['density'])
